# %%
from astropy.io import fits
from astropy.table import Table

# %%
with fits.open('./EUC_LE3_VMPZ-ID_HPEXPOSURES-102018211_20241120T173847.128639Z_0.11.fits') as hdul:
    data = hdul[1].data
    header = hdul[0].header   
    
hdul.info()
# Out:
# Filename: ./EUC_LE3_VMPZ-ID_HPEXPOSURES-102018211_20241120T173847.128639Z_0.11.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      20   ()
#   1  INFO_MAP      1 BinTableHDU     25   19120R x 2C   [K, E]

# %%
Table(data)
# Out:
# <Table length=19120>
#   PIXEL       WEIGHT
#   int64      float32
# ---------- -----------
# 2248749056 -1.6375e+30
# 2248749057 -1.6375e+30
# 2248749058 -1.6375e+30
# 2248749059 -1.6375e+30
# 2248749060 -1.6375e+30
# 2248749061 -1.6375e+30
# 2248749062 -1.6375e+30
# 2248749063 -1.6375e+30
# 2248749064 -1.6375e+30
#        ...         ...
# 2248776306 -1.6375e+30
# 2248776307 -1.6375e+30
# 2248776448 -1.6375e+30
# 2248776449 -1.6375e+30
# 2248776450 -1.6375e+30
# 2248776451 -1.6375e+30
# 2248776704 -1.6375e+30
# 2248776705 -1.6375e+30
# 2248776706 -1.6375e+30
# 2248776707 -1.6375e+30
