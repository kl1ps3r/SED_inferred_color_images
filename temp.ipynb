# %%
import pickle as pkl

import os

cwd = os.getcwd()
cwd
# Out:
# '/Users/admin/Documents/SED_inferred_color_images'

# %%
with open('/Users/admin/Documents/creating_spiral_images/opt_4/kwargs.pkl', 'rb') as f:
    data = pkl.load(f)
    kwargs_model, kwargs_data, multiband_list = data['params'], data['models'], data['multiband_list']

# %%
kwargs_model
# Out:
# {'kwargs_lens': [{'theta_E': 1.8,
#    'center_x': 0.3686891993185043,
#    'center_y': -0.040460506267520104,
#    'e1': -0.1,
#    'e2': 0.2},
#   {'theta_E': 0.4,
#    'center_x': 0.3686891993185043,
#    'center_y': -0.040460506267520104}],
#  'kwargs_source': [{'amp': 50.039652990817935,
#    'R_sersic': 0.2,
#    'n_sersic': 4.0,
#    'center_x': 0.1,
#    'center_y': 0.0,
#    'e1': 0.7,
#    'e2': 0.2}],
#  'kwargs_lens_light': [{'amp': 4.728031572813563,
#    'R_sersic': 2.5,
#    'n_sersic': 1.5,
#    'center_x': 0.3686891993185043,
#    'center_y': -0.040460506267520104,
#    'e1': -0.1,
#    'e2': 0.2}],
#  'kwargs_ps': [],
#  'kwargs_special': {},
#  'kwargs_extinction': [],
#  'kwargs_tracer_source': []}
